# %% [markdown]
# # BOXPLOTS

# %% [markdown]
# ## CW Sliding

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)
import matplotlib.lines as mlines
from matplotlib.lines import Line2D     
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerPatch


data_a = [[100.0, 100.0, 50.0, 50.0, 83.33333333333334, 50.0, 33.33333333333333, 66.66666666666666,
           100.0, 33.33333333333333, 80.0, 83.33333333333334, 83.33333333333334, 100.0, 83.33333333333334,
           100.0, 80.0, 83.33333333333334, 100.0, 66.66666666666666, 20.0, 33.33333333333333,
           83.33333333333334, 83.33333333333334, 80.0, 83.33333333333334], 
          [100.0, 83.33333333333334, 100.0, 100.0, 50.0, 66.66666666666666, 50.0, 83.33333333333334, 80.0,
           66.66666666666666, 100.0, 83.33333333333334, 100.0, 100.0, 100.0, 80.0, 100.0, 100.0, 100.0,
           66.66666666666666, 40.0, 33.33333333333333, 100.0, 100.0, 100.0, 83.33333333333334],
          [100.0, 100.0, 66.66666666666666, 100.0, 50.0, 66.66666666666666, 50.0, 83.33333333333334,
           80.0, 50.0, 100.0, 83.33333333333334, 100.0, 100.0, 83.33333333333334, 80.0, 100.0,
           100.0, 100.0, 33.33333333333333, 40.0, 50.0, 83.33333333333334, 83.33333333333334,
           80.0, 83.33333333333334]]


data_b = [[75.0, 87.5, 50.0, 87.5, 50.0, 62.5, 75.0, 50.0, 66.66666666666666, 62.5, 71.42857142857143,
           75.0, 87.5, 100.0, 100.0, 71.42857142857143, 83.33333333333334, 87.5, 100.0, 62.5, 28.57142857142857, 
           75.0, 100.0, 87.5, 57.14285714285714, 100.0], 
          [87.5, 75.0, 75.0, 100.0, 37.5, 62.5, 62.5, 87.5, 83.33333333333334, 62.5, 71.42857142857143,
           87.5, 87.5, 100.0, 87.5, 100.0, 100.0, 75.0, 100.0, 75.0, 28.57142857142857, 37.5,
           100.0, 87.5, 71.42857142857143, 87.5],
          [100.0, 87.5, 87.5, 100.0, 62.5, 62.5, 87.5, 87.5, 83.33333333333334, 75.0, 71.42857142857143,
           100.0, 87.5, 100.0, 87.5, 100.0, 100.0, 87.5, 100.0, 50.0, 28.57142857142857,
           25.0, 100.0, 87.5, 57.14285714285714, 87.5]]

data_c = [[80.0, 80.0, 50.0, 80.0, 30.0, 60.0, 80.0, 60.0, 75.0, 50.0, 88.88888888888889, 60.0, 100.0, 100.0,
           90.0, 100.0, 100.0, 70.0, 100.0, 60.0, 11.11111111111111, 70.0, 100.0, 90.0, 77.77777777777779, 100.0],
          [80.0, 100.0, 70.0, 100.0, 40.0, 80.0, 90.0, 70.0, 87.5, 70.0, 88.88888888888889, 80.0, 90.0, 60.0,
           90.0, 100.0, 100.0, 100.0, 100.0, 60.0, 33.33333333333333, 40.0, 90.0, 90.0, 77.77777777777779, 90.0],
          [90.0, 100.0, 70.0, 100.0, 40.0, 60.0, 80.0, 80.0, 87.5, 50.0, 100.0, 80.0, 80.0,
           80.0, 90.0, 100.0, 100.0, 90.0, 100.0, 60.0, 22.22222222222222, 40.0, 90.0, 90.0,
           77.77777777777779, 90.0]]

left_positions= [-0.4, 2, 4.4]
          
middle_positions = [0.2, 2.6, 5]

right_positions= [0.8, 3.2, 5.6]




plt.figure()

plt.boxplot(data_a, positions = left_positions, boxprops={'facecolor': '#000000','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_b, positions = middle_positions, boxprops={'facecolor': '#FFFFFF','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_c, positions = right_positions, boxprops={'facecolor': 'grey','edgecolor': '#000000'},patch_artist=True)



black_square = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
                          markersize=12, label='No overlap')


white_square1 = mlines.Line2D([], [], color='white', marker='s', linestyle='solid',
                          markersize=12,label='30% overlap', markeredgecolor='black')

white_square2 = mlines.Line2D([], [], color='grey', marker='s', linestyle='solid',
                          markersize=12,label='50% overlap', markeredgecolor='black')

plt.legend(handles=[black_square, white_square1, white_square2],  bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

ticks = [0.2, 2.6, 5]
labels= ['Random Rorest', 'L-SVM', 'SVM(RBF)']

plt.xlabel("ML Model",fontsize=18)
plt.ylabel("Accuracy",fontsize=18)

plt.tight_layout()
plt.xticks(ticks, labels,fontsize=18)
# Out:
# ([<matplotlib.axis.XTick at 0x7f97b1554580>,
# ...
#  [Text(0.2, 0, 'Random Rorest'),
#   Text(2.6, 0, 'L-SVM'),
#   Text(5.0, 0, 'SVM(RBF)')])

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)
import matplotlib.lines as mlines
from matplotlib.lines import Line2D     
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerPatch
from matplotlib.font_manager import FontProperties

fontP = FontProperties()
fontP.set_size('x-large')


data_a = [[100.0, 100.0, 57.14285714285715, 57.14285714285715, 80.0, 57.14285714285715, 0.0,
          66.66666666666666, 100.0, 33.33333333333333, 80.0, 85.71428571428571, 80.0, 100.0,
          80.0, 100.0, 80.0, 85.71428571428571, 100.0, 66.66666666666666, 33.33333333333333,
          33.33333333333333, 85.71428571428571, 80.0, 80.0, 85.71428571428571],
          [100.0, 80.0, 100.0, 100.0, 0.0, 74.99999999999999, 40.0, 85.71428571428571, 80.0,
           66.66666666666666, 100.0, 85.71428571428571, 100.0, 100.0, 100.0, 80.0, 100.0,
           100.0, 100.0, 66.66666666666666, 40.0, 33.33333333333333, 100.0, 100.0, 100.0, 85.71428571428571],
          [100.0, 100.0, 66.66666666666666, 100.0, 0.0, 74.99999999999999, 40.0, 85.71428571428571,
           80.0, 57.14285714285715, 100.0, 85.71428571428571, 100.0, 100.0, 80.0, 80.0, 100.0,
           100.0, 100.0, 33.33333333333333, 40.0, 57.14285714285715, 85.71428571428571,
           80.0, 80.0, 85.71428571428571]]

data_b = [[75.0, 85.71428571428571, 50.0, 85.71428571428571, 33.33333333333333, 66.66666666666666,
           66.66666666666666, 50.0, 66.66666666666666, 57.14285714285715, 66.66666666666666, 80.0,
           88.8888888888889, 100.0, 100.0, 66.66666666666666, 80.0, 85.71428571428571, 100.0, 57.14285714285715,
           44.44444444444445, 80.0, 100.0, 85.71428571428571, 57.14285714285715, 100.0],
          [88.8888888888889, 66.66666666666666, 80.0, 100.0, 0.0, 72.72727272727273, 57.14285714285715,
           85.71428571428571, 80.0, 66.66666666666666, 66.66666666666666, 85.71428571428571,
           85.71428571428571, 100.0, 85.71428571428571, 100.0, 100.0, 75.0, 100.0, 75.0, 28.571428571428577,
           0.0, 100.0, 85.71428571428571, 74.99999999999999, 88.8888888888889], 
          [100.0, 85.71428571428571, 85.71428571428571, 100.0, 57.14285714285715, 72.72727272727273,
           85.71428571428571, 85.71428571428571, 80.0, 75.0, 66.66666666666666, 100.0,
           85.71428571428571, 100.0, 85.71428571428571, 100.0, 100.0, 88.8888888888889, 100.0,
           50.0, 28.571428571428577, 0.0, 100.0, 85.71428571428571, 57.14285714285715,88.8888888888889]]



data_c = [[83.33333333333333, 74.99999999999999, 44.44444444444445, 83.33333333333333, 22.222222222222225,           
           60.0, 74.99999999999999, 60.0, 74.99999999999999, 54.54545454545454, 88.8888888888889, 66.66666666666666,
           100.0, 100.0, 90.9090909090909, 100.0, 100.0, 72.72727272727272, 100.0, 60.0, 20.000000000000004,     
           72.72727272727272, 100.0, 88.8888888888889, 80.0, 100.0], 
          [80.00000000000001, 100.0, 76.92307692307693, 100.0, 0.0, 83.33333333333333, 90.9090909090909,
           76.92307692307693, 85.71428571428571, 72.72727272727272, 88.8888888888889, 80.00000000000001,
           88.8888888888889, 33.333333333333336, 88.8888888888889, 100.0, 100.0, 100.0, 100.0,
           66.66666666666666, 25.0, 40.00000000000001, 90.9090909090909, 90.9090909090909, 80.0, 90.9090909090909],
          [90.9090909090909, 100.0, 66.66666666666666, 100.0, 0.0, 66.66666666666666, 80.00000000000001,
           83.33333333333333, 85.71428571428571, 61.53846153846154, 100.0, 80.00000000000001,
           80.00000000000001, 74.99999999999999, 88.8888888888889, 100.0, 100.0, 90.9090909090909,
           100.0, 60.0, 22.222222222222225, 25.0, 90.9090909090909, 88.8888888888889, 80.0, 90.9090909090909]]

left_positions= [-0.4, 2, 4.4]
          
middle_positions = [0.2, 2.6, 5]

right_positions= [0.8, 3.2, 5.6]




plt.figure()

plt.boxplot(data_a, positions = left_positions, boxprops={'facecolor': '#000000','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_b, positions = middle_positions, boxprops={'facecolor': '#FFFFFF','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_c, positions = right_positions, boxprops={'facecolor': 'grey','edgecolor': '#000000'},patch_artist=True)



black_square = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
                          markersize=12, label='No overlap')


white_square1 = mlines.Line2D([], [], color='white', marker='s', linestyle='solid',
                          markersize=12,label='30% overlap', markeredgecolor='black')

white_square2 = mlines.Line2D([], [], color='grey', marker='s', linestyle='solid',
                          markersize=12,label='50% overlap', markeredgecolor='black')

plt.legend(handles=[black_square, white_square1, white_square2],  bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

ticks = [0.2, 2.6, 5]
labels= ['Random Rorest', 'L-SVM', 'SVM(RBF)']

plt.xlabel("ML Model",fontsize=18)
plt.ylabel("F1-Score",fontsize=18)

plt.tight_layout()
plt.xticks(ticks, labels,fontsize=18)
# Out:
# ([<matplotlib.axis.XTick at 0x7f97b15ed0d0>,
# ...
#  [Text(0.2, 0, 'Random Rorest'),
#   Text(2.6, 0, 'L-SVM'),
#   Text(5.0, 0, 'SVM(RBF)')])

# %%
[75.0, 87.5, 62.5, 100.0, 87.5, 75.0, 62.5, 62.5, 100.0, 50.0, 85.71428571428571, 62.5,
           75.0, 87.5, 87.5, 71.42857142857143, 100.0, 87.5, 100.0, 25.0, 42.857142857142854, 62.5,
           75.0, 87.5, 71.42857142857143, 87.5]
# Out:
# [75.0,
#  87.5,
#  62.5,
#  100.0,
#  87.5,
#  75.0,
#  62.5,
#  62.5,
#  100.0,
#  50.0,
#  85.71428571428571,
#  62.5,
#  75.0,
#  87.5,
#  87.5,
#  71.42857142857143,
#  100.0,
#  87.5,
#  100.0,
#  25.0,
#  42.857142857142854,
#  62.5,
#  75.0,
#  87.5,
#  71.42857142857143,
#  87.5]

# %% [markdown]
# # CW GAN

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)
import matplotlib.lines as mlines
from matplotlib.lines import Line2D     
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerPatch


data_a = [[100.0, 100.0, 50.0, 50.0, 83.33333333333334, 50.0, 33.33333333333333, 66.66666666666666,
           100.0, 33.33333333333333, 80.0, 83.33333333333334, 83.33333333333334, 100.0, 83.33333333333334,
           100.0, 80.0, 83.33333333333334, 100.0, 66.66666666666666, 20.0, 33.33333333333333,
           83.33333333333334, 83.33333333333334, 80.0, 83.33333333333334], 
          [100.0, 83.33333333333334, 100.0, 100.0, 50.0, 66.66666666666666, 50.0, 83.33333333333334, 80.0,
           66.66666666666666, 100.0, 83.33333333333334, 100.0, 100.0, 100.0, 80.0, 100.0, 100.0, 100.0,
           66.66666666666666, 40.0, 33.33333333333333, 100.0, 100.0, 100.0, 83.33333333333334],
          [100.0, 100.0, 66.66666666666666, 100.0, 50.0, 66.66666666666666, 50.0, 83.33333333333334,
           80.0, 50.0, 100.0, 83.33333333333334, 100.0, 100.0, 83.33333333333334, 80.0, 100.0,
           100.0, 100.0, 33.33333333333333, 40.0, 50.0, 83.33333333333334, 83.33333333333334,
           80.0, 83.33333333333334]]


data_b = [[75.0, 87.5, 62.5, 100.0, 87.5, 75.0, 62.5, 62.5, 100.0, 50.0, 85.71428571428571, 62.5,
           75.0, 87.5, 87.5, 71.42857142857143, 100.0, 87.5, 100.0, 25.0, 42.857142857142854, 62.5,
           75.0, 87.5, 71.42857142857143, 87.5], 
          [87.5, 75.0, 75.0, 100.0, 62.5, 75.0, 50.0, 62.5, 71.42857142857143, 50.0,
           85.71428571428571, 87.5, 100.0, 87.5, 100.0, 85.71428571428571, 85.71428571428571,
           100.0, 85.71428571428571, 50.0, 28.57142857142857, 50.0, 62.5, 75.0, 57.14285714285714, 75.0],
          [87.5, 87.5, 62.5, 87.5, 62.5, 75.0, 50.0, 75.0, 71.42857142857143, 37.5, 85.71428571428571,
           75.0, 100.0, 87.5, 87.5, 85.71428571428571, 100.0, 100.0, 85.71428571428571, 25.0,
           28.57142857142857, 50.0, 62.5, 75.0, 57.14285714285714, 100.0]]

data_c = [[90.0, 90.0, 50.0, 80.0, 60.0, 60.0, 80.0, 60.0, 88.88888888888889, 80.0,
           66.66666666666666, 70.0, 80.0, 80.0, 100.0, 100.0, 88.88888888888889, 80.0,
           100.0, 60.0, 55.55555555555556, 70.0, 90.0, 80.0, 77.77777777777779, 70.0],
          [90.0, 90.0, 50.0, 90.0, 80.0, 60.0, 70.0, 60.0, 77.77777777777779, 60.0,
           77.77777777777779, 80.0, 70.0, 70.0, 90.0, 100.0, 66.66666666666666, 80.0,
           88.88888888888889, 60.0, 33.33333333333333, 60.0, 80.0, 80.0, 77.77777777777779,
           60.0], 
          [90.0, 90.0, 60.0, 90.0, 70.0, 70.0, 70.0, 60.0, 88.88888888888889, 80.0, 77.77777777777779,
           80.0, 60.0, 70.0, 100.0, 100.0, 66.66666666666666, 80.0, 100.0, 60.0, 33.33333333333333,
           60.0, 90.0, 90.0, 88.88888888888889, 70.0]]

left_positions= [-0.4, 2, 4.4]
          
middle_positions = [0.2, 2.6, 5]

right_positions= [0.8, 3.2, 5.6]




plt.figure()

plt.boxplot(data_a, positions = left_positions, boxprops={'facecolor': '#000000','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_b, positions = middle_positions, boxprops={'facecolor': '#FFFFFF','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_c, positions = right_positions, boxprops={'facecolor': 'grey','edgecolor': '#000000'},patch_artist=True)



black_square = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
                          markersize=12, label='No overlap')


white_square1 = mlines.Line2D([], [], color='white', marker='s', linestyle='solid',
                          markersize=12,label='30% overlap', markeredgecolor='black')

white_square2 = mlines.Line2D([], [], color='grey', marker='s', linestyle='solid',
                          markersize=12,label='50% overlap', markeredgecolor='black')

plt.legend(handles=[black_square, white_square1, white_square2],  bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

ticks = [0.2, 2.6, 5]
labels= ['Random Rorest', 'L-SVM', 'SVM(RBF)']

plt.xlabel("ML Model",fontsize=18)
plt.ylabel("Accuracy",fontsize=18)

plt.tight_layout()
plt.xticks(ticks, labels,fontsize=18)
# Out:
# ([<matplotlib.axis.XTick at 0x7f97b188a0d0>,
# ...
#  [Text(0.2, 0, 'Random Rorest'),
#   Text(2.6, 0, 'L-SVM'),
#   Text(5.0, 0, 'SVM(RBF)')])

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)
import matplotlib.lines as mlines
from matplotlib.lines import Line2D     
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerPatch
from matplotlib.font_manager import FontProperties

fontP = FontProperties()
fontP.set_size('x-large')


data_a = [[100.0, 100.0, 57.14285714285715, 57.14285714285715, 80.0, 57.14285714285715, 0.0,
          66.66666666666666, 100.0, 33.33333333333333, 80.0, 85.71428571428571, 80.0, 100.0,
          80.0, 100.0, 80.0, 85.71428571428571, 100.0, 66.66666666666666, 33.33333333333333,
          33.33333333333333, 85.71428571428571, 80.0, 80.0, 85.71428571428571],
          [100.0, 80.0, 100.0, 100.0, 0.0, 74.99999999999999, 40.0, 85.71428571428571, 80.0,
           66.66666666666666, 100.0, 85.71428571428571, 100.0, 100.0, 100.0, 80.0, 100.0,
           100.0, 100.0, 66.66666666666666, 40.0, 33.33333333333333, 100.0, 100.0, 100.0, 85.71428571428571],
          [100.0, 100.0, 66.66666666666666, 100.0, 0.0, 74.99999999999999, 40.0, 85.71428571428571,
           80.0, 57.14285714285715, 100.0, 85.71428571428571, 100.0, 100.0, 80.0, 80.0, 100.0,
           100.0, 100.0, 33.33333333333333, 40.0, 57.14285714285715, 85.71428571428571,
           80.0, 80.0, 85.71428571428571]]

data_b = [[66.66666666666666, 85.71428571428571, 57.14285714285715, 100.0, 85.71428571428571,
           66.66666666666666, 57.14285714285715, 66.66666666666666, 100.0, 60.0, 88.8888888888889,
           72.72727272727273, 75.0, 88.8888888888889, 85.71428571428571, 74.99999999999999,
           100.0, 85.71428571428571, 100.0, 40.00000000000001, 50.0, 57.14285714285715, 80.0,
           85.71428571428571, 75.0, 85.71428571428571], 
          [85.71428571428571, 66.66666666666666, 66.66666666666666, 100.0, 57.14285714285715, 74.99999999999999,
           33.333333333333336, 66.66666666666666, 74.99999999999999, 60.0, 88.8888888888889, 88.8888888888889,
           100.0, 88.8888888888889, 100.0, 85.71428571428571, 88.8888888888889, 100.0, 85.71428571428571,
           50.0, 28.571428571428577, 50.0, 66.66666666666666, 66.66666666666666, 57.14285714285715, 75.0],
          [85.71428571428571, 85.71428571428571, 57.14285714285715, 88.8888888888889, 66.66666666666666,
           74.99999999999999, 33.333333333333336, 80.0, 74.99999999999999, 44.44444444444445, 88.8888888888889,
           80.0, 100.0, 88.8888888888889, 85.71428571428571, 85.71428571428571, 100.0, 100.0,
           85.71428571428571, 25.0, 28.571428571428577, 50.0, 66.66666666666666, 66.66666666666666,
           57.14285714285715, 100.0]]



data_c = [[88.8888888888889, 88.8888888888889, 54.54545454545454, 83.33333333333333, 66.66666666666666,
           71.42857142857143, 74.99999999999999, 66.66666666666666, 90.9090909090909, 85.71428571428571,
           66.66666666666666, 76.92307692307692, 83.33333333333334, 83.33333333333334, 100.0, 100.0,
           90.9090909090909, 80.0, 100.0, 66.66666666666666, 66.66666666666666, 76.92307692307693,
           88.8888888888889, 85.71428571428571, 83.33333333333333, 76.92307692307692],
          [88.8888888888889, 85.71428571428571, 44.44444444444445, 90.9090909090909, 74.99999999999999,
           71.42857142857143, 66.66666666666666, 66.66666666666666, 80.00000000000001, 66.66666666666666,
           80.00000000000001, 83.33333333333334, 76.92307692307692, 66.66666666666666, 90.9090909090909,
           100.0, 72.72727272727272, 80.0, 88.8888888888889, 66.66666666666666, 50.0, 60.0, 80.0,
           83.33333333333334, 80.00000000000001, 66.66666666666666], 
          [88.8888888888889, 85.71428571428571, 50.0, 90.9090909090909, 57.14285714285715,
           80.0, 66.66666666666666, 66.66666666666666, 90.9090909090909, 85.71428571428571, 80.00000000000001,
           83.33333333333334, 66.66666666666666, 66.66666666666666, 100.0, 100.0, 72.72727272727272,
           80.0, 100.0, 66.66666666666666, 50.0, 60.0, 88.8888888888889, 90.9090909090909,
           88.8888888888889, 76.92307692307692]]

left_positions= [-0.4, 2, 4.4]
          
middle_positions = [0.2, 2.6, 5]

right_positions= [0.8, 3.2, 5.6]




plt.figure()

plt.boxplot(data_a, positions = left_positions, boxprops={'facecolor': '#000000','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_b, positions = middle_positions, boxprops={'facecolor': '#FFFFFF','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_c, positions = right_positions, boxprops={'facecolor': 'grey','edgecolor': '#000000'},patch_artist=True)



black_square = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
                          markersize=12, label='No overlap')


white_square1 = mlines.Line2D([], [], color='white', marker='s', linestyle='solid',
                          markersize=12,label='30% overlap', markeredgecolor='black')

white_square2 = mlines.Line2D([], [], color='grey', marker='s', linestyle='solid',
                          markersize=12,label='50% overlap', markeredgecolor='black')

plt.legend(handles=[black_square, white_square1, white_square2],  bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

ticks = [0.2, 2.6, 5]
labels= ['Random Rorest', 'L-SVM', 'SVM(RBF)']

plt.xlabel("ML Model",fontsize=18)
plt.ylabel("F1-Score",fontsize=18)

plt.tight_layout()
plt.xticks(ticks, labels,fontsize=18)
# Out:
# ([<matplotlib.axis.XTick at 0x7f97c0774580>,
# ...
#  [Text(0.2, 0, 'Random Rorest'),
#   Text(2.6, 0, 'L-SVM'),
#   Text(5.0, 0, 'SVM(RBF)')])

# %% [markdown]
# # Acute Stress Sliding

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)
import matplotlib.lines as mlines
from matplotlib.lines import Line2D     
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerPatch


data_a = [[71.42857142857143,
 100.0,
 100.0,
 100.0,
 100.0,
 85.71428571428571,
 85.71428571428571,
 100.0,
 100.0,
 87.5,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 85.71428571428571,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0], [85.71428571428571,
 100.0,
 100.0,
 100.0,
 100.0,
 85.71428571428571,
 85.71428571428571,
 100.0,
 100.0,
 87.5,
 85.71428571428571,
 85.71428571428571,
 100.0,
 100.0,
 100.0,
 100.0,
 83.33333333333334,
 100.0,
 85.71428571428571,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0], [85.71428571428571,
 100.0,
 100.0,
 100.0,
 100.0,
 85.71428571428571,
 85.71428571428571,
 100.0,
 100.0,
 87.5,
 85.71428571428571,
 85.71428571428571,
 100.0,
 100.0,
 100.0,
 100.0,
 83.33333333333334,
 100.0,
 85.71428571428571,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0]]

data_b = [[90.0,
 100.0,
 100.0,
 100.0,
 100.0,
 90.0,
 90.0,
 100.0,
 100.0,
 100.0,
 90.0,
 100.0,
 100.0,
 90.0,
 100.0,
 100.0,
 88.88888888888889,
 100.0,
 88.88888888888889,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 80.0], [100.0,
 100.0,
 90.0,
 100.0,
 100.0,
 90.0,
 90.0,
 100.0,
 100.0,
 100.0,
 90.0,
 90.0,
 100.0,
 100.0,
 100.0,
 100.0,
 88.88888888888889,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0], [100.0,
 100.0,
 90.0,
 100.0,
 100.0,
 90.0,
 90.0,
 100.0,
 100.0,
 100.0,
 80.0,
 90.0,
 100.0,
 100.0,
 90.9090909090909,
 100.0,
 88.88888888888889,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0]]

data_c = [[76.92307692307693,
 100.0,
 92.3076923076923,
 100.0,
 100.0,
 92.3076923076923,
 84.61538461538461,
 100.0,
 100.0,
 100.0,
 92.3076923076923,
 100.0,
 92.85714285714286,
 92.85714285714286,
 93.33333333333333,
 100.0,
 90.9090909090909,
 100.0,
 91.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 84.61538461538461],[92.3076923076923,
 100.0,
 92.3076923076923,
 100.0,
 100.0,
 92.3076923076923,
 84.61538461538461,
 100.0,
 100.0,
 100.0,
 92.3076923076923,
 100.0,
 92.85714285714286,
 100.0,
 100.0,
 100.0,
 81.81818181818183,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0], [92.3076923076923,
 100.0,
 92.3076923076923,
 100.0,
 100.0,
 92.3076923076923,
 84.61538461538461,
 100.0,
 100.0,
 100.0,
 92.3076923076923,
 100.0,
 92.85714285714286,
 100.0,
 100.0,
 100.0,
 81.81818181818183,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0]]

left_positions= [-0.4, 2, 4.4]
          
middle_positions = [0.2, 2.6, 5]

right_positions= [0.8, 3.2, 5.6]




plt.figure()

plt.boxplot(data_a, positions = left_positions, boxprops={'facecolor': '#000000','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_b, positions = middle_positions, boxprops={'facecolor': '#FFFFFF','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_c, positions = right_positions, boxprops={'facecolor': 'grey','edgecolor': '#000000'},patch_artist=True)



black_square = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
                          markersize=12, label='No overlap')


white_square1 = mlines.Line2D([], [], color='white', marker='s', linestyle='solid',
                          markersize=12,label='30% overlap', markeredgecolor='black')

white_square2 = mlines.Line2D([], [], color='grey', marker='s', linestyle='solid',
                          markersize=12,label='50% overlap', markeredgecolor='black')

plt.legend(handles=[black_square, white_square1, white_square2],  bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

ticks = [0.2, 2.6, 5]
labels= ['Random Rorest', 'L-SVM', 'SVM(RBF)']

plt.xlabel("ML Model",fontsize=18)
plt.ylabel("Accuracy",fontsize=18)

plt.tight_layout()
plt.xticks(ticks, labels,fontsize=18)
# Out:
# ([<matplotlib.axis.XTick at 0x7f979013ebb0>,
# ...
#  [Text(0.2, 0, 'Random Rorest'),
#   Text(2.6, 0, 'L-SVM'),
#   Text(5.0, 0, 'SVM(RBF)')])

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)
import matplotlib.lines as mlines
from matplotlib.lines import Line2D     
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerPatch
from matplotlib.font_manager import FontProperties

fontP = FontProperties()
fontP.set_size('x-large')


data_a = [[50.0,
 100.0,
 100.0,
 100.0,
 100.0,
 66.66666666666666,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0], [80.0,
 100.0,
 100.0,
 100.0,
 100.0,
 66.66666666666666,
 66.66666666666666,
 100.0,
 100.0,
 66.66666666666666,
 80.0,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 66.66666666666666,
 100.0,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0], [80.0,
 100.0,
 100.0,
 100.0,
 100.0,
 66.66666666666666,
 66.66666666666666,
 100.0,
 100.0,
 66.66666666666666,
 80.0,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 66.66666666666666,
 100.0,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0]]

data_b = [[85.71428571428571,
 100.0,
 100.0,
 100.0,
 100.0,
 80.0,
 80.0,
 100.0,
 100.0,
 100.0,
 80.0,
 100.0,
 100.0,
 80.0,
 100.0,
 100.0,
 80.0,
 100.0,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 66.66666666666666], [100.0,
 100.0,
 80.0,
 100.0,
 100.0,
 80.0,
 80.0,
 100.0,
 100.0,
 100.0,
 85.71428571428571,
 80.0,
 100.0,
 100.0,
 100.0,
 100.0,
 80.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0], [100.0,
 100.0,
 80.0,
 100.0,
 100.0,
 80.0,
 80.0,
 100.0,
 100.0,
 100.0,
 66.66666666666666,
 80.0,
 100.0,
 100.0,
 88.8888888888889,
 100.0,
 80.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0]]


data_c = [[40.0,
 100.0,
 88.8888888888889,
 100.0,
 100.0,
 85.71428571428571,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 85.71428571428571,
 100.0,
 88.8888888888889,
 85.71428571428571,
 80.0,
 100.0,
 80.0,
 100.0,
 80.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 80.0], [85.71428571428571,
 100.0,
 88.8888888888889,
 100.0,
 100.0,
 85.71428571428571,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 88.8888888888889,
 100.0,
 85.71428571428571,
 100.0,
 100.0,
 100.0,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0], [85.71428571428571,
 100.0,
 88.8888888888889,
 100.0,
 100.0,
 85.71428571428571,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 88.8888888888889,
 100.0,
 85.71428571428571,
 100.0,
 100.0,
 100.0,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0]]

left_positions= [-0.4, 2, 4.4]
          
middle_positions = [0.2, 2.6, 5]

right_positions= [0.8, 3.2, 5.6]




plt.figure()

plt.boxplot(data_a, positions = left_positions, boxprops={'facecolor': '#000000','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_b, positions = middle_positions, boxprops={'facecolor': '#FFFFFF','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_c, positions = right_positions, boxprops={'facecolor': 'grey','edgecolor': '#000000'},patch_artist=True)



black_square = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
                          markersize=12, label='No overlap')


white_square1 = mlines.Line2D([], [], color='white', marker='s', linestyle='solid',
                          markersize=12,label='30% overlap', markeredgecolor='black')

white_square2 = mlines.Line2D([], [], color='grey', marker='s', linestyle='solid',
                          markersize=12,label='50% overlap', markeredgecolor='black')

plt.legend(handles=[black_square, white_square1, white_square2],  bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

ticks = [0.2, 2.6, 5]
labels= ['Random Rorest', 'L-SVM', 'SVM(RBF)']

plt.xlabel("ML Model",fontsize=18)
plt.ylabel("F1-Score",fontsize=18)

plt.tight_layout()
plt.xticks(ticks, labels,fontsize=18)
# Out:
# ([<matplotlib.axis.XTick at 0x7f97a040c250>,
# ...
#  [Text(0.2, 0, 'Random Rorest'),
#   Text(2.6, 0, 'L-SVM'),
#   Text(5.0, 0, 'SVM(RBF)')])

# %% [markdown]
# # Acute Stress GAN

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)
import matplotlib.lines as mlines
from matplotlib.lines import Line2D     
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerPatch


data_a = [[71.42857142857143,
 100.0,
 100.0,
 100.0,
 100.0,
 85.71428571428571,
 85.71428571428571,
 100.0,
 100.0,
 87.5,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 85.71428571428571,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0], [85.71428571428571,
 100.0,
 100.0,
 100.0,
 100.0,
 85.71428571428571,
 85.71428571428571,
 100.0,
 100.0,
 87.5,
 85.71428571428571,
 85.71428571428571,
 100.0,
 100.0,
 100.0,
 100.0,
 83.33333333333334,
 100.0,
 85.71428571428571,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0], [85.71428571428571,
 100.0,
 100.0,
 100.0,
 100.0,
 85.71428571428571,
 85.71428571428571,
 100.0,
 100.0,
 87.5,
 85.71428571428571,
 85.71428571428571,
 100.0,
 100.0,
 100.0,
 100.0,
 83.33333333333334,
 100.0,
 85.71428571428571,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0]]

data_b = [[80.0,
 90.0,
 90.0,
 100.0,
 100.0,
 80.0,
 70.0,
 90.0,
 88.88888888888889,
 72.72727272727273,
 80.0,
 90.0,
 100.0,
 90.0,
 90.9090909090909,
 80.0,
 77.77777777777779,
 100.0,
 70.0,
 100.0,
 100.0,
 80.0,
 88.88888888888889,
 88.88888888888889,
 60.0], [80.0,
 90.0,
 100.0,
 100.0,
 100.0,
 80.0,
 80.0,
 90.0,
 88.88888888888889,
 72.72727272727273,
 80.0,
 90.0,
 100.0,
 90.0,
 90.9090909090909,
 80.0,
 66.66666666666666,
 100.0,
 90.0,
 100.0,
 100.0,
 80.0,
 88.88888888888889,
 88.88888888888889,
 30.0], [80.0,
 90.0,
 100.0,
 100.0,
 100.0,
 80.0,
 80.0,
 90.0,
 88.88888888888889,
 72.72727272727273,
 80.0,
 90.0,
 100.0,
 90.0,
 90.9090909090909,
 80.0,
 66.66666666666666,
 100.0,
 90.0,
 100.0,
 100.0,
 80.0,
 88.88888888888889,
 88.88888888888889,
 30.0]]

data_c = [[78.57142857142857,
 92.85714285714286,
 92.85714285714286,
 78.57142857142857,
 71.42857142857143,
 85.71428571428571,
 71.42857142857143,
 78.57142857142857,
 92.3076923076923,
 80.0,
 71.42857142857143,
 64.28571428571429,
 85.71428571428571,
 71.42857142857143,
 93.33333333333333,
 100.0,
 76.92307692307693,
 69.23076923076923,
 64.28571428571429,
 76.92307692307693,
 92.85714285714286,
 85.71428571428571,
 69.23076923076923,
 69.23076923076923,
 71.42857142857143], [78.57142857142857,
 92.85714285714286,
 92.85714285714286,
 85.71428571428571,
 71.42857142857143,
 92.85714285714286,
 64.28571428571429,
 78.57142857142857,
 100.0,
 80.0,
 85.71428571428571,
 57.14285714285714,
 85.71428571428571,
 78.57142857142857,
 93.33333333333333,
 100.0,
 84.61538461538461,
 84.61538461538461,
 71.42857142857143,
 84.61538461538461,
 85.71428571428571,
 85.71428571428571,
 76.92307692307693,
 84.61538461538461,
 78.57142857142857], [57.14285714285715,
 80.0,
 80.0,
 80.0,
 50.0,
 80.0,
 28.57142857142857,
 72.72727272727272,
 100.0,
 40.0,
 80.0,
 25.0,
 80.0,
 66.66666666666666,
 88.8888888888889,
 100.0,
 74.99999999999999,
 50.0,
 60.0,
 66.66666666666666,
 66.66666666666666,
 74.99999999999999,
 57.14285714285715,
 50.0,
 66.66666666666666]]

left_positions= [-0.4, 2, 4.4]
          
middle_positions = [0.2, 2.6, 5]

right_positions= [0.8, 3.2, 5.6]




plt.figure()

plt.boxplot(data_a, positions = left_positions, boxprops={'facecolor': '#000000','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_b, positions = middle_positions, boxprops={'facecolor': '#FFFFFF','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_c, positions = right_positions, boxprops={'facecolor': 'grey','edgecolor': '#000000'},patch_artist=True)



black_square = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
                          markersize=12, label='No overlap')


white_square1 = mlines.Line2D([], [], color='white', marker='s', linestyle='solid',
                          markersize=12,label='30% overlap', markeredgecolor='black')

white_square2 = mlines.Line2D([], [], color='grey', marker='s', linestyle='solid',
                          markersize=12,label='50% overlap', markeredgecolor='black')

plt.legend(handles=[black_square, white_square1, white_square2],  bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

ticks = [0.2, 2.6, 5]
labels= ['Random Rorest', 'L-SVM', 'SVM(RBF)']

plt.xlabel("ML Model",fontsize=18)
plt.ylabel("Accuracy",fontsize=18)

plt.tight_layout()
plt.xticks(ticks, labels,fontsize=18)
# Out:
# ([<matplotlib.axis.XTick at 0x7f97a81943d0>,
# ...
#  [Text(0.2, 0, 'Random Rorest'),
#   Text(2.6, 0, 'L-SVM'),
#   Text(5.0, 0, 'SVM(RBF)')])

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)
import matplotlib.lines as mlines
from matplotlib.lines import Line2D     
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerPatch
from matplotlib.font_manager import FontProperties

fontP = FontProperties()
fontP.set_size('x-large')


data_a = [[50.0,
 100.0,
 100.0,
 100.0,
 100.0,
 66.66666666666666,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0], [80.0,
 100.0,
 100.0,
 100.0,
 100.0,
 66.66666666666666,
 66.66666666666666,
 100.0,
 100.0,
 66.66666666666666,
 80.0,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 66.66666666666666,
 100.0,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0], [80.0,
 100.0,
 100.0,
 100.0,
 100.0,
 66.66666666666666,
 66.66666666666666,
 100.0,
 100.0,
 66.66666666666666,
 80.0,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 66.66666666666666,
 100.0,
 66.66666666666666,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0,
 100.0]]

data_b = [[75.0,
 85.71428571428571,
 88.8888888888889,
 100.0,
 100.0,
 50.0,
 40.0,
 85.71428571428571,
 85.71428571428571,
 66.66666666666666,
 66.66666666666666,
 80.0,
 100.0,
 80.0,
 85.71428571428571,
 66.66666666666666,
 66.66666666666666,
 100.0,
 40.0,
 100.0,
 100.0,
 66.66666666666666,
 80.0,
 80.0,
 60.0], [75.0,
 85.71428571428571,
 100.0,
 100.0,
 100.0,
 50.0,
 66.66666666666666,
 85.71428571428571,
 85.71428571428571,
 66.66666666666666,
 66.66666666666666,
 80.0,
 100.0,
 80.0,
 85.71428571428571,
 66.66666666666666,
 57.14285714285715,
 100.0,
 80.0,
 100.0,
 100.0,
 66.66666666666666,
 80.0,
 80.0,
 36.36363636363637], [75.0,
 85.71428571428571,
 100.0,
 100.0,
 100.0,
 50.0,
 66.66666666666666,
 85.71428571428571,
 85.71428571428571,
 66.66666666666666,
 66.66666666666666,
 80.0,
 100.0,
 80.0,
 85.71428571428571,
 66.66666666666666,
 57.14285714285715,
 100.0,
 80.0,
 100.0,
 100.0,
 66.66666666666666,
 80.0,
 80.0,
 36.36363636363637]]

data_c = [[57.14285714285715,
 80.0,
 100.0,
 66.66666666666666,
 50.0,
 80.0,
 50.0,
 72.72727272727272,
 88.8888888888889,
 40.0,
 44.44444444444445,
 44.44444444444445,
 66.66666666666666,
 60.0,
 88.8888888888889,
 100.0,
 66.66666666666666,
 33.33333333333333,
 54.54545454545454,
 66.66666666666666,
 85.71428571428571,
 74.99999999999999,
 33.333333333333336,
 40.0,
 60.0], [57.14285714285715,
 80.0,
 80.0,
 80.0,
 50.0,
 80.0,
 28.57142857142857,
 72.72727272727272,
 100.0,
 40.0,
 80.0,
 25.0,
 80.0,
 66.66666666666666,
 88.8888888888889,
 100.0,
 74.99999999999999,
 50.0,
 60.0,
 66.66666666666666,
 66.66666666666666,
 74.99999999999999,
 57.14285714285715,
 50.0,
 66.66666666666666], [78.57142857142857,
 92.85714285714286,
 92.85714285714286,
 85.71428571428571,
 71.42857142857143,
 92.85714285714286,
 64.28571428571429,
 78.57142857142857,
 100.0,
 80.0,
 85.71428571428571,
 57.14285714285714,
 85.71428571428571,
 78.57142857142857,
 93.33333333333333,
 100.0,
 84.61538461538461,
 84.61538461538461,
 71.42857142857143,
 84.61538461538461,
 85.71428571428571,
 85.71428571428571,
 76.92307692307693,
 84.61538461538461,
 78.57142857142857]]



left_positions= [-0.4, 2, 4.4]
          
middle_positions = [0.2, 2.6, 5]

right_positions= [0.8, 3.2, 5.6]




plt.figure()

plt.boxplot(data_a, positions = left_positions, boxprops={'facecolor': '#000000','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_b, positions = middle_positions, boxprops={'facecolor': '#FFFFFF','edgecolor': '#000000'},patch_artist=True)
plt.boxplot(data_c, positions = right_positions, boxprops={'facecolor': 'grey','edgecolor': '#000000'},patch_artist=True)



black_square = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
                          markersize=12, label='No overlap')


white_square1 = mlines.Line2D([], [], color='white', marker='s', linestyle='solid',
                          markersize=12,label='30% overlap', markeredgecolor='black')

white_square2 = mlines.Line2D([], [], color='grey', marker='s', linestyle='solid',
                          markersize=12,label='50% overlap', markeredgecolor='black')

plt.legend(handles=[black_square, white_square1, white_square2],  bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

ticks = [0.2, 2.6, 5]
labels= ['Random Rorest', 'L-SVM', 'SVM(RBF)']

plt.xlabel("ML Model",fontsize=18)
plt.ylabel("F1-Score",fontsize=18)

plt.tight_layout()
plt.xticks(ticks, labels,fontsize=18)
# Out:
# ([<matplotlib.axis.XTick at 0x7f97d1dbc940>,
# ...
#  [Text(0.2, 0, 'Random Rorest'),
#   Text(2.6, 0, 'L-SVM'),
#   Text(5.0, 0, 'SVM(RBF)')])
